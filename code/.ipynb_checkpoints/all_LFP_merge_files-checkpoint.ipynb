# %% [markdown]
# # Neural Mass Model
# Merge colossus results <br>
# March 2021

# %%
# Add paths
import sys, os
import ipynbname
nb_fname = ipynbname.name()
nb_path = ipynbname.path()
sys.path.insert(0, os.path.dirname(nb_fname))
data_dir = os.path.abspath(os.path.join(os.path.dirname(nb_fname), '..', 'results/')) # parent directory of "Sim" directory

#CHANGED FOR COLOSSUS RESULTS (16f) FROM PABLO'S RESULTS (15f)
#filename = 'trial_'+str(0)+'_rate_'+str(v0)+'_gex_'+\
#                                str(float("{0:.16f}".format(var[0])))+'_gin_'+str(float("{0:.16f}".format(var[1])))

# %%
# File ID
#IDs = ["Sim0","Sim1"]
#IDs = ["Sim0","Sim2"]
IDs = ["SimA", "SimB"]

# External input rates
ext_rates = [1.5,2.0] # (spikes/s)
#ext_rates = [2.0] # (spikes/s)
experiment_ID = '/merged_files_' + IDs[0] + '_' + IDs[1]
print((data_dir + '/merged_files_' + IDs[0] + '_' + IDs[1]))
print(experiment_ID)
# Out:
# /Users/oliviabeyerbruvik/Desktop/ei_hurst/results/merged_files_SimA_SimB
# /merged_files_SimA_SimB

# %% [markdown]
# ## MERGED FILES

# %%
import numpy as np
import sys,os
import pickle
import matplotlib.pyplot as plt
import random
import time

# Import tools
import tools

Network_params = {
    "exc_exc_recurrent": 0.178,
    "exc_inh_recurrent": 0.233,
    "inh_inh_recurrent": -2.70,
    "inh_exc_recurrent": -2.01
}

# New seed
random.seed(int(time.time()))

# Type of processing: either ratio of conductances (0) or chemogenetic
# manipulations (1)
proc_type = 0

# Manipulation variable
label_var = 'g'

# File ID
#IDs = ["Sim0","Sim1"]
##IDs = ["Sim1"]

# External input rates
#ext_rates = [1.5,2.0] # (spikes/s)
## ext_rates = [2.0] # (spikes/s)

# Automatic search of g_ex and g_in, or the chemo. variable range
if proc_type == 0:
    g_ex_range = []
    g_in_range = []

cont_var_range = []

g_ex_list = []
g_in_list = []
g_ratio_list = []

# Load all files
for id in IDs:
    if proc_type == 0:
        # Limits
        limits = [5.,15.]
        g_ex_range_aux = []
        g_in_range_aux = []
    else:
        cont_var_range_aux = []
        # Limits
        # limits = [-75.,-69.]
        limits = [-53.,-51.5]

    dir = os.path.abspath(os.path.join(data_dir+'/' +id))
    ldir = os.listdir(dir)
    ldir.sort()

    for filename in ldir:
        if '.AMPA' in filename:
            print(filename)
            # g_ex
            if proc_type == 0:
                m1 = filename.find("gex_")+4
                m2 = filename.find("_gin_")
                g_ex = float(filename[m1:m2])
                #print(g_ex)
                g_ex_list.append(g_ex)

                # g_in
                m1 = filename.find("gin_")+4
                m2 = filename.find(".AMPA")
                g_in = float(filename[m1:m2])
                #print(g_in)

                # Ext freq
                m1 = filename.find("rate_")+5
                m2 = filename.find("_gex")
                v0 = float(filename[m1:m2])
                #print(v0)

                g_ratio = -g_in*Network_params["inh_exc_recurrent"]/(g_ex*Network_params["exc_exc_recurrent"])
                print(g_ratio)
                g_ratio_list.append(g_ratio)
                if (g_ex == 1.0 or g_in == 1.0) and (v0 in ext_rates) and (g_ratio>= limits[0] and g_ratio <=limits[1]):
                    g_ex_range_aux.append(g_ex)
                    g_in_range_aux.append(g_in)
                    print("WITHIN LIMITS")
                    
#Network_params = {
 #   "exc_exc_recurrent": 0.178,
 #   "exc_inh_recurrent": 0.233,
 #   "inh_inh_recurrent": -2.70,
 #   "inh_exc_recurrent": -2.01
#}

            else:
                # cont_var
                m1 = filename.find(cont_var+"_")+len(cont_var)+1
                m2 = filename.find(".AMPA")
                var = float(filename[m1:m2])

                # Ext freq
                m1 = filename.find("rate_")+5
                m2 = filename.find("_"+cont_var)
                v0 = float(filename[m1:m2])

                if v0 in ext_rates and (var>= limits[0] and var <=limits[1]):
                    cont_var_range_aux.append(var)


    # Select only unique values
    if proc_type == 0:
        g_ex_range_aux = np.array(g_ex_range_aux)
        g_in_range_aux = np.array(g_in_range_aux)

        g_ex_range_aux = np.unique(g_ex_range_aux)
        g_in_range_aux = np.unique(g_in_range_aux)

        # Add to g_ex_range and g_in_range
        random.shuffle(g_ex_range_aux)
        random.shuffle(g_in_range_aux)
        g_ex_range.append(g_ex_range_aux)
        g_in_range.append(g_in_range_aux)
    else:
        cont_var_range_aux = np.array(cont_var_range_aux)
        cont_var_range_aux = np.unique(cont_var_range_aux)

        # Add to cont_var_range
        random.shuffle(cont_var_range_aux)
        cont_var_range.append(cont_var_range_aux)

# For conductances, create a single array with all combinations
if proc_type == 0:
    for exp_cont,exp in enumerate(IDs):
        cont_var_range_aux = []

        for ggex in g_ex_range[exp_cont]:
            for ggin in g_in_range[exp_cont]:
                cont_var_range_aux.append([ggex,ggin])

        cont_var_range.append(cont_var_range_aux)

# Cluster of results
cluster_0_rate_1 = [np.array([]),np.array([])]
cluster_1_rate_1 = [np.array([]),np.array([])]
cluster_2_rate_1 = [np.array([]),np.array([])]
cluster_0_rate_2 = [np.array([]),np.array([])]
cluster_1_rate_2 = [np.array([]),np.array([])]
cluster_2_rate_2 = [np.array([]),np.array([])]

# Average values
g_cluster_0 = []
g_cluster_1 = []
g_cluster_2 = []

print("Merging LFP traces...")

# Loop
for exp_cont,exp in enumerate(IDs):
    for v0 in ext_rates:

        for var in cont_var_range[exp_cont]:
        # for ggex in g_ex_range[exp_cont]:
        #     for ggin in g_in_range[exp_cont]:
            # Select only g values within canonical axes
            if proc_type == 0:
                if var[0]== 1. or var[1]== 1.:
                    # Print simulation case
                    var_ratio = -var[1]*Network_params["inh_exc_recurrent"]/(var[0]*Network_params["exc_exc_recurrent"])
                    # print("\nExt. rate = %s sp/s, g_ex = %s, g_in = %s, g = %s \n" % (v0,var[0],var[1],var_ratio))
                    filename = 'trial_'+str(0)+'_rate_'+str(v0)+'_gex_'+\
                                str(float("{0:.16f}".format(var[0])))+'_gin_'+str(float("{0:.16f}".format(var[1])))
                    ## print(filename)
                    continue_processing = True
                else:
                    continue_processing = False
            else:
                # Print simulation case
                var_ratio = var
                print("\nExt. rate = %s sp/s, variable = %s \n" % (v0,var))
                filename = 'trial_'+str(0)+'_rate_'+str(v0)+'_'+cont_var+'_'+\
                            str(float("{0:.15f}".format(var)))
                continue_processing = True

            # Load results
            if continue_processing:
                try:
                    with open(data_dir+ '/' + exp+'/'+filename+".AMPA", "rb") as f:
                        AMPA_current = pickle.load(open(data_dir+'/' +exp+'/'+filename+".AMPA", "rb"),encoding='latin1')
                        GABA_current = pickle.load(open(data_dir+'/' +exp+'/'+filename+".GABA", "rb"),encoding='latin1')
                        t_sim = pickle.load(open(data_dir+'/' +exp+'/'+filename+".times", "rb"),encoding='latin1')
                        simstep = pickle.load(open(data_dir+'/' +exp+'/'+filename+".dt", "rb"),encoding='latin1')

                        AMPA_current = np.concatenate((AMPA_current,np.zeros(10)))
                        GABA_current = np.concatenate((GABA_current,np.zeros(10)))

                        if v0 == 1.5:
                            if var_ratio < 7.5 and len(cluster_0_rate_1[0])/100000 < 20:
                                g_cluster_0.append(var_ratio)
                                cluster_0_rate_1[0] = np.concatenate((cluster_0_rate_1[0],AMPA_current))
                                cluster_0_rate_1[1] = np.concatenate((cluster_0_rate_1[1],GABA_current))
                            elif var_ratio > 11 and len(cluster_2_rate_1[0])/100000 < 20:
                                g_cluster_2.append(var_ratio)
                                cluster_2_rate_1[0] = np.concatenate((cluster_2_rate_1[0],AMPA_current))
                                cluster_2_rate_1[1] = np.concatenate((cluster_2_rate_1[1],GABA_current))
                            else:
                                if len(cluster_1_rate_1[0])/100000 < 20:
                                    g_cluster_1.append(var_ratio)
                                    cluster_1_rate_1[0] = np.concatenate((cluster_1_rate_1[0],AMPA_current))
                                    cluster_1_rate_1[1] = np.concatenate((cluster_1_rate_1[1],GABA_current))
                        else:
                            print("var_ratio:", var_ratio, "len(cluster_0_rate_2[0])/100000:", len(cluster_0_rate_2[0])/100000)
                            if var_ratio < 7.5 and len(cluster_0_rate_2[0])/100000 < 20:
                                cluster_0_rate_2[0] = np.concatenate((cluster_0_rate_2[0],AMPA_current))
                                cluster_0_rate_2[1] = np.concatenate((cluster_0_rate_2[1],GABA_current))
                            elif var_ratio > 11 and len(cluster_2_rate_2[0])/100000 < 20:
                                cluster_2_rate_2[0] = np.concatenate((cluster_2_rate_2[0],AMPA_current))
                                cluster_2_rate_2[1] = np.concatenate((cluster_2_rate_2[1],GABA_current))
                            else:
                                if len(cluster_1_rate_2[0])/100000 < 20:
                                    cluster_1_rate_2[0] = np.concatenate((cluster_1_rate_2[0],AMPA_current))
                                    cluster_1_rate_2[1] = np.concatenate((cluster_1_rate_2[1],GABA_current))

                except Exception as e:
                    print(e)
                    None

# Print number of samples
print("Rate 1.5 sp/s: %s, %s, %s" % (len(cluster_0_rate_1[0])/100000,len(cluster_1_rate_1[0])/100000,len(cluster_2_rate_1[0])/100000))
print("Rate 2 sp/s: %s, %s, %s" % (len(cluster_0_rate_2[0])/100000,len(cluster_1_rate_2[0])/100000,len(cluster_2_rate_2[0])/100000))
print("mean(g) = %s,%s,%s" % (np.mean(g_cluster_0),np.mean(g_cluster_1),np.mean(g_cluster_2)))

#######################################################################
# Save data
#os.mkdir(data_dir + experiment_ID)


def saveData(experiment_id,filename,extension,data):
    pickle.dump(data,open(data_dir+'/' +experiment_id+'/'+filename+extension, "wb"))

# AMPA and GABA
# A) 1.5 sp/s
filename = 'trial_'+str(0)+'_rate_'+str(1.5)+'_gex_'+str(1.78289473684)+'_gin_'+str(1.0)
saveData(experiment_ID,filename,".AMPA",cluster_0_rate_1[0])
saveData(experiment_ID,filename,".GABA",cluster_0_rate_1[1])
# Save time array
saveData(experiment_ID,filename,".times",t_sim)
# Save time step
saveData(experiment_ID,filename,".dt",simstep)

filename = 'trial_'+str(0)+'_rate_'+str(1.5)+'_gex_'+str(1.20394736842)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".AMPA",cluster_1_rate_1[0])
saveData(experiment_ID,filename,".GABA",cluster_1_rate_1[1])
# Save time array
saveData(experiment_ID,filename,".times",t_sim)
# Save time step
saveData(experiment_ID,filename,".dt",simstep)

filename = 'trial_'+str(0)+'_rate_'+str(1.5)+'_gex_'+str(0.842105263158)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".AMPA",cluster_2_rate_1[0])
saveData(experiment_ID,filename,".GABA",cluster_2_rate_1[1])
# Save time array
saveData(experiment_ID,filename,".times",t_sim)
# Save time step
saveData(experiment_ID,filename,".dt",simstep)
########################################################################
# B) 2 sp/s
filename = 'trial_'+str(0)+'_rate_'+str(2.0)+'_gex_'+str(1.78289473684)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".AMPA",cluster_0_rate_2[0])
saveData(experiment_ID,filename,".GABA",cluster_0_rate_2[1])
# Save time array
saveData(experiment_ID,filename,".times",t_sim)
# Save time step
saveData(experiment_ID,filename,".dt",simstep)

filename = 'trial_'+str(0)+'_rate_'+str(2.0)+'_gex_'+str(1.20394736842)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".AMPA",cluster_1_rate_2[0])
saveData(experiment_ID,filename,".GABA",cluster_1_rate_2[1])
# Save time array
saveData(experiment_ID,filename,".times",t_sim)
# Save time step
saveData(experiment_ID,filename,".dt",simstep)

filename = 'trial_'+str(0)+'_rate_'+str(2.0)+'_gex_'+str(0.842105263158)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".AMPA",cluster_2_rate_2[0])
saveData(experiment_ID,filename,".GABA",cluster_2_rate_2[1])
# Save time array
saveData(experiment_ID,filename,".times",t_sim)
# Save time step
saveData(experiment_ID,filename,".dt",simstep)
# Out:
# trial_0_rate_1.5_gex_0.625_gin_1.0.AMPA
# 18.06741573033708
# trial_0_rate_1.5_gex_0.697368421053_gin_1.0.AMPA
# 16.192495230010525
# trial_0_rate_1.5_gex_0.769736842105_gin_1.0.AMPA
# 14.670123883612042
# WITHIN LIMITS
# trial_0_rate_1.5_gex_0.842105263158_gin_1.0.AMPA
# 13.409410112357872
# WITHIN LIMITS
# trial_0_rate_1.5_gex_0.914473684211_gin_1.0.AMPA
# 12.34823377252614
# WITHIN LIMITS
# trial_0_rate_1.5_gex_0.986842105263_gin_1.0.AMPA
# 11.442696629215314
# WITHIN LIMITS
# trial_0_rate_1.5_gex_1.0_gin_0.5.AMPA
# 5.646067415730337
# WITHIN LIMITS
# trial_0_rate_1.5_gex_1.0_gin_0.557894736842.AMPA
# 6.299822590182134
# WITHIN LIMITS
# trial_0_rate_1.5_gex_1.0_gin_0.615789473684.AMPA
# 6.953577764633933
# WITHIN LIMITS
# trial_0_rate_1.5_gex_1.0_gin_0.673684210526.AMPA
# 7.60733293908573
# WITHIN LIMITS
# trial_0_rate_1.5_gex_1.0_gin_0
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.49342105263_gin_1.0.AMPA
# 7.561253279223951
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.54166666667_gin_1.0.AMPA
# 7.324627998769464
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.56578947368_gin_1.0.AMPA
# 7.211783589859823
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.63815789474_gin_1.0.AMPA
# 6.893190740476761
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.69444444444_gin_1.0.AMPA
# 6.66421072022378
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.71052631579_gin_1.0.AMPA
# 6.6015557476211315
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.78289473684_gin_1.0.AMPA
# 6.333595920236343
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.84722222222_gin_1.0.AMPA
# 6.113035397489823
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.85526315789_gin_1.0.AMPA
# 6.0865407602354775
# WITHIN LIMITS
# trial_0_rate_2.0_gex_1.92763157895_gin_1.0.AMPA
# 5.858035816995492
# WITHIN LIMITS
# trial_0_rate_2.0_gex_2.0_gin_1.0.AMPA
# 5.646067415730337
# WITHIN LIMITS
# Merging LFP traces...
# var_ratio: 8.372704850621139 len(cluster_0_rate_2[0])/100000: 0.0
# var_ratio: 7.561253279223951 len(cluster_0_rate_2[0])/100000: 0.0
# var_ratio: 6.6015557476211315 len(cluster_0_rate_2[0])/100000: 0.0
# var_ratio: 13.409410112357872 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 7.946317103614588 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 9.3792595321504 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 14.79863985807809 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 12.837374334677527 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 6.953577764633933 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 14.144884683648876 len(cluster_0_rate_2[0])/100000: 2.0
# var_ratio: 8.261088113537529 len(cluster_0_rate_2[0])/100000: 2.0
# var_ratio: 8.914843288000617 len(cluster_0_rate_2[0])/100000: 2.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 2.0
# var_ratio: 10.222353636904213 len(cluster_0_rate_2[0])/100000: 3.0
# var_ratio: 6.299822590182134 len(cluster_0_rate_2[0])/100000: 3.0
# var_ratio: 10.87610881135601 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 12.183619160248313 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 9.568598462452416 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 11.292134831460674 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 7.60733293908573 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 13.491129509219661 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 11.442696629215314 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 9.979095897555974 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 8.847445847355552 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 6.893190740476761 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 7.211783589859823 len(cluster_0_rate_2[0])/100000: 6.0
# var_ratio: 14.670123883612042 len(cluster_0_rate_2[0])/100000: 7.0
# var_ratio: 6.333595920236343 len(cluster_0_rate_2[0])/100000: 7.0
# var_ratio: 5.858035816995492 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 6.0865407602354775 len(cluster_0_rate_2[0])/100000: 9.0
# var_ratio: 12.34823377252614 len(cluster_0_rate_2[0])/100000: 10.0
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.69444444444_gin_1.0.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_0.777777777778_gin_1.0.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.23611111111_gin_1.0.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_0.930555555556_gin_1.0.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.38888888889_gin_1.0.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.0_gin_1.23333333333.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.0_gin_0.866666666667.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.0_gin_0.744444444444.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.0_gin_1.11111111111.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.0_gin_0.622222222222.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.54166666667_gin_1.0.AMPA'
# [Errno 2] No such file or directory: '/Users/oliviabeyerbruvik/Desktop/ei_hurst/results/SimB/trial_0_rate_1.5_gex_1.84722222222_gin_1.0.AMPA'
# var_ratio: 6.333595920236343 len(cluster_0_rate_2[0])/100000: 10.0
# var_ratio: 6.66421072022378 len(cluster_0_rate_2[0])/100000: 11.0
# var_ratio: 9.3792595321504 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 14.51845906901672 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 9.13521020074044 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 7.561253279223951 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 12.13483146066836 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 12.34823377252614 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 11.442696629215314 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 6.6015557476211315 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 7.211783589859823 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 13.409410112357872 len(cluster_0_rate_2[0])/100000: 14.0
# var_ratio: 8.13033707864518 len(cluster_0_rate_2[0])/100000: 14.0
# var_ratio: 6.0865407602354775 len(cluster_0_rate_2[0])/100000: 14.0
# var_ratio: 7.946317103614588 len(cluster_0_rate_2[0])/100000: 15.0
# var_ratio: 9.979095897555974 len(cluster_0_rate_2[0])/100000: 15.0
# var_ratio: 8.847445847355552 len(cluster_0_rate_2[0])/100000: 15.0
# var_ratio: 6.893190740476761 len(cluster_0_rate_2[0])/100000: 15.0
# var_ratio: 5.858035816995492 len(cluster_0_rate_2[0])/100000: 16.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 17.0
# var_ratio: 8.372704850621139 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 13.92696629209719 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 9.786516853936346 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 8.261088113537529 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 8.406367041193484 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 9.568598462452416 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 12.183619160248313 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 10.222353636904213 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 7.60733293908573 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 14.79863985807809 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 11.292134831460674 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 12.546816479388204 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 8.914843288000617 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 12.837374334677527 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 13.491129509219661 len(cluster_0_rate_2[0])/100000: 19.0
# var_ratio: 6.299822590182134 len(cluster_0_rate_2[0])/100000: 19.0
# var_ratio: 6.953577764633933 len(cluster_0_rate_2[0])/100000: 20.0
# var_ratio: 14.144884683648876 len(cluster_0_rate_2[0])/100000: 20.0
# var_ratio: 10.87610881135601 len(cluster_0_rate_2[0])/100000: 20.0
# var_ratio: 7.02621722846191 len(cluster_0_rate_2[0])/100000: 20.0
# var_ratio: 14.670123883612042 len(cluster_0_rate_2[0])/100000: 20.0
# var_ratio: 7.324627998769464 len(cluster_0_rate_2[0])/100000: 20.0
# var_ratio: 6.113035397489823 len(cluster_0_rate_2[0])/100000: 20.0
# Rate 1.5 sp/s: 20.0, 20.0, 20.0
# Rate 2 sp/s: 20.0, 20.0, 20.0
# mean(g) = 6.353023776170177,8.872608242418483,13.06182467750445

# %%
import numpy as np
import sys,os
import pickle
import matplotlib.pyplot as plt
import random
import time

# Import tools
import tools

Network_params = {
    "exc_exc_recurrent": 0.178,
    "exc_inh_recurrent": 0.233,
    "inh_inh_recurrent": -2.70,
    "inh_exc_recurrent": -2.01
}

# New seed
random.seed(int(time.time()))

# Type of processing: either ratio of conductances (0) or chemogenetic
# manipulations (1)
proc_type = 0

# Manipulation variable
label_var = 'g'

# File ID
#IDs = ["Sim0","Sim1"]
##IDs = ["Sim1"]

# External input rates
#ext_rates = [1.5,2.0] # (spikes/s)
## ext_rates = [2.0] # (spikes/s)

# Automatic search of g_ex and g_in, or the chemo. variable range
if proc_type == 0:
    g_ex_range = []
    g_in_range = []

cont_var_range = []

g_ex_list = []
g_in_list = []
g_ratio_list = []

# Load all files
for id in IDs:
    if proc_type == 0:
        # Limits
        limits = [5.,15.]
        g_ex_range_aux = []
        g_in_range_aux = []
    else:
        cont_var_range_aux = []
        # Limits
        # limits = [-75.,-69.]
        limits = [-53.,-51.5]

    dir = os.path.abspath(os.path.join(data_dir+'/'+id))
    ldir = os.listdir(dir)
    ldir.sort()

    for filename in ldir:
        if 'in_AMPA' in filename:
            # g_ex
            if proc_type == 0:
                m1 = filename.find("gex_")+4
                m2 = filename.find("_gin_")
                g_ex = float(filename[m1:m2])
                #print(g_ex)
                g_ex_list.append(g_ex)

                # g_in
                m1 = filename.find("gin_")+4
                m2 = filename.find(".in_AMPA")
                g_in = float(filename[m1:m2])
                #print(g_in)

                # Ext freq
                m1 = filename.find("rate_")+5
                m2 = filename.find("_gex")
                v0 = float(filename[m1:m2])
                #print(v0)

                g_ratio = -g_in*Network_params["inh_exc_recurrent"]/(g_ex*Network_params["exc_exc_recurrent"])
                #print(g_ratio)
                g_ratio_list.append(g_ratio)
                if (g_ex == 1.0 or g_in == 1.0) and (v0 in ext_rates) and (g_ratio>= limits[0] and g_ratio <=limits[1]):
                    g_ex_range_aux.append(g_ex)
                    g_in_range_aux.append(g_in)

            else:
                # cont_var
                m1 = filename.find(cont_var+"_")+len(cont_var)+1
                m2 = filename.find(".in_AMPA")
                var = float(filename[m1:m2])

                # Ext freq
                m1 = filename.find("rate_")+5
                m2 = filename.find("_"+cont_var)
                v0 = float(filename[m1:m2])

                if v0 in ext_rates and (var>= limits[0] and var <=limits[1]):
                    cont_var_range_aux.append(var)


    # Select only unique values
    if proc_type == 0:
        g_ex_range_aux = np.array(g_ex_range_aux)
        g_in_range_aux = np.array(g_in_range_aux)

        g_ex_range_aux = np.unique(g_ex_range_aux)
        g_in_range_aux = np.unique(g_in_range_aux)

        # Add to g_ex_range and g_in_range
        random.shuffle(g_ex_range_aux)
        random.shuffle(g_in_range_aux)
        g_ex_range.append(g_ex_range_aux)
        g_in_range.append(g_in_range_aux)
    else:
        cont_var_range_aux = np.array(cont_var_range_aux)
        cont_var_range_aux = np.unique(cont_var_range_aux)

        # Add to cont_var_range
        random.shuffle(cont_var_range_aux)
        cont_var_range.append(cont_var_range_aux)

# For conductances, create a single array with all combinations
if proc_type == 0:
    for exp_cont,exp in enumerate(IDs):
        cont_var_range_aux = []

        for ggex in g_ex_range[exp_cont]:
            for ggin in g_in_range[exp_cont]:
                cont_var_range_aux.append([ggex,ggin])

        cont_var_range.append(cont_var_range_aux)

# Cluster of results
cluster_0_rate_1 = [np.array([]),np.array([])]
cluster_1_rate_1 = [np.array([]),np.array([])]
cluster_2_rate_1 = [np.array([]),np.array([])]
cluster_0_rate_2 = [np.array([]),np.array([])]
cluster_1_rate_2 = [np.array([]),np.array([])]
cluster_2_rate_2 = [np.array([]),np.array([])]

# Average values
g_cluster_0 = []
g_cluster_1 = []
g_cluster_2 = []

print("Merging LFP traces...")

# Loop
for exp_cont,exp in enumerate(IDs):
    for v0 in ext_rates:

        for var in cont_var_range[exp_cont]:
        # for ggex in g_ex_range[exp_cont]:
        #     for ggin in g_in_range[exp_cont]:
            # Select only g values within canonical axes
            if proc_type == 0:
                if var[0]== 1. or var[1]== 1.:
                    # Print simulation case
                    var_ratio = -var[1]*Network_params["inh_exc_recurrent"]/(var[0]*Network_params["exc_exc_recurrent"])
                    # print("\nExt. rate = %s sp/s, g_ex = %s, g_in = %s, g = %s \n" % (v0,var[0],var[1],var_ratio))
                    filename = 'trial_'+str(0)+'_rate_'+str(v0)+'_gex_'+\
                                str(float("{0:.16f}".format(var[0])))+'_gin_'+str(float("{0:.16f}".format(var[1])))
                    ## print(filename)
                    continue_processing = True
                else:
                    continue_processing = False
            else:
                # Print simulation case
                var_ratio = var
                print("\nExt. rate = %s sp/s, variable = %s \n" % (v0,var))
                filename = 'trial_'+str(0)+'_rate_'+str(v0)+'_'+cont_var+'_'+\
                            str(float("{0:.15f}".format(var)))
                continue_processing = True

            # Load results
            if continue_processing:
                try:
                    with open(data_dir+'/'+exp+'/'+filename+".in_AMPA", "rb") as f:
                        AMPA_current = pickle.load(open(data_dir+'/'+exp+'/'+filename+".in_AMPA", "rb"),encoding='latin1')
                        GABA_current = pickle.load(open(data_dir+'/'+exp+'/'+filename+".in_GABA", "rb"),encoding='latin1')
                        t_sim = pickle.load(open(data_dir+'/'+exp+'/'+filename+".times", "rb"),encoding='latin1')
                        simstep = pickle.load(open(data_dir+'/'+exp+'/'+filename+".dt", "rb"),encoding='latin1')

                        AMPA_current = np.concatenate((AMPA_current,np.zeros(10)))
                        GABA_current = np.concatenate((GABA_current,np.zeros(10)))

                        if v0 == 1.5:
                            if var_ratio < 7.5 and len(cluster_0_rate_1[0])/100000 < 20:
                                g_cluster_0.append(var_ratio)
                                cluster_0_rate_1[0] = np.concatenate((cluster_0_rate_1[0],AMPA_current))
                                cluster_0_rate_1[1] = np.concatenate((cluster_0_rate_1[1],GABA_current))
                            elif var_ratio > 11 and len(cluster_2_rate_1[0])/100000 < 20:
                                g_cluster_2.append(var_ratio)
                                cluster_2_rate_1[0] = np.concatenate((cluster_2_rate_1[0],AMPA_current))
                                cluster_2_rate_1[1] = np.concatenate((cluster_2_rate_1[1],GABA_current))
                            else:
                                if len(cluster_1_rate_1[0])/100000 < 20:
                                    g_cluster_1.append(var_ratio)
                                    cluster_1_rate_1[0] = np.concatenate((cluster_1_rate_1[0],AMPA_current))
                                    cluster_1_rate_1[1] = np.concatenate((cluster_1_rate_1[1],GABA_current))
                        else:
                            print("var_ratio:", var_ratio, "len(cluster_0_rate_2[0])/100000:", len(cluster_0_rate_2[0])/100000)
                            if var_ratio < 7.5 and len(cluster_0_rate_2[0])/100000 < 20:
                                cluster_0_rate_2[0] = np.concatenate((cluster_0_rate_2[0],AMPA_current))
                                cluster_0_rate_2[1] = np.concatenate((cluster_0_rate_2[1],GABA_current))
                            elif var_ratio > 11 and len(cluster_2_rate_2[0])/100000 < 20:
                                cluster_2_rate_2[0] = np.concatenate((cluster_2_rate_2[0],AMPA_current))
                                cluster_2_rate_2[1] = np.concatenate((cluster_2_rate_2[1],GABA_current))
                            else:
                                if len(cluster_1_rate_2[0])/100000 < 20:
                                    cluster_1_rate_2[0] = np.concatenate((cluster_1_rate_2[0],AMPA_current))
                                    cluster_1_rate_2[1] = np.concatenate((cluster_1_rate_2[1],GABA_current))

                except Exception as e:
                    print(e)
                    None

# Print number of samples
print("Rate 1.5 sp/s: %s, %s, %s" % (len(cluster_0_rate_1[0])/100000,len(cluster_1_rate_1[0])/100000,len(cluster_2_rate_1[0])/100000))
print("Rate 2 sp/s: %s, %s, %s" % (len(cluster_0_rate_2[0])/100000,len(cluster_1_rate_2[0])/100000,len(cluster_2_rate_2[0])/100000))
print("mean(g) = %s,%s,%s" % (np.mean(g_cluster_0),np.mean(g_cluster_1),np.mean(g_cluster_2)))

#######################################################################
# Save data

def saveData(experiment_id,filename,extension,data):
    pickle.dump(data,open(data_dir+experiment_id+'/'+filename+extension, "wb"))

# AMPA and GABA
# A) 1.5 sp/s
filename = 'trial_'+str(0)+'_rate_'+str(1.5)+'_gex_'+str(1.78289473684)+'_gin_'+str(1.0)
saveData(experiment_ID,filename,".in_AMPA",cluster_0_rate_1[0])
saveData(experiment_ID,filename,".in_GABA",cluster_0_rate_1[1])

filename = 'trial_'+str(0)+'_rate_'+str(1.5)+'_gex_'+str(1.20394736842)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".in_AMPA",cluster_1_rate_1[0])
saveData(experiment_ID,filename,".in_GABA",cluster_1_rate_1[1])

filename = 'trial_'+str(0)+'_rate_'+str(1.5)+'_gex_'+str(0.842105263158)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".in_AMPA",cluster_2_rate_1[0])
saveData(experiment_ID,filename,".in_GABA",cluster_2_rate_1[1])

########################################################################
# B) 2 sp/s
filename = 'trial_'+str(0)+'_rate_'+str(2.0)+'_gex_'+str(1.78289473684)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".in_AMPA",cluster_0_rate_2[0])
saveData(experiment_ID,filename,".in_GABA",cluster_0_rate_2[1])

filename = 'trial_'+str(0)+'_rate_'+str(2.0)+'_gex_'+str(1.20394736842)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".in_AMPA",cluster_1_rate_2[0])
saveData(experiment_ID,filename,".in_GABA",cluster_1_rate_2[1])

filename = 'trial_'+str(0)+'_rate_'+str(2.0)+'_gex_'+str(0.842105263158)+'_gin_'+str(1.0)
# AMPA and GABA
saveData(experiment_ID,filename,".in_AMPA",cluster_2_rate_2[0])
saveData(experiment_ID,filename,".in_GABA",cluster_2_rate_2[1])
# Out:
# Merging LFP traces...
# var_ratio: 11.442696629213483 len(cluster_0_rate_2[0])/100000: 0.0
# var_ratio: 6.3335959202288645 len(cluster_0_rate_2[0])/100000: 0.0
# var_ratio: 5.858035817003489 len(cluster_0_rate_2[0])/100000: 1.0
# var_ratio: 8.847445847330011 len(cluster_0_rate_2[0])/100000: 2.0
# var_ratio: 6.086540760219937 len(cluster_0_rate_2[0])/100000: 2.0
# var_ratio: 7.946317103620474 len(cluster_0_rate_2[0])/100000: 3.0
# var_ratio: 13.40941011235955 len(cluster_0_rate_2[0])/100000: 3.0
# var_ratio: 6.601555747623164 len(cluster_0_rate_2[0])/100000: 3.0
# var_ratio: 8.372704850644011 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 6.893190740490049 len(cluster_0_rate_2[0])/100000: 4.0
# var_ratio: 14.67012388360703 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 9.979095897569897 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 9.379259532142198 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 8.261088113542284 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 14.798639858072146 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 10.876108811354229 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 13.491129509166173 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 12.183619160260202 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 8.91484328799527 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 12.837374334713187 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 7.607332939089295 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 5.0
# var_ratio: 9.568598462448255 len(cluster_0_rate_2[0])/100000: 6.0
# var_ratio: 6.953577764636309 len(cluster_0_rate_2[0])/100000: 6.0
# var_ratio: 6.2998225901833225 len(cluster_0_rate_2[0])/100000: 7.0
# var_ratio: 11.292134831460674 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 10.222353636901241 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 14.14488468361916 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 12.348233772532534 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 7.561253279215957 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 7.21178358984043 len(cluster_0_rate_2[0])/100000: 8.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 9.0
# var_ratio: 13.40941011235955 len(cluster_0_rate_2[0])/100000: 10.0
# var_ratio: 6.953577764636309 len(cluster_0_rate_2[0])/100000: 10.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 11.0
# var_ratio: 8.91484328799527 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 8.261088113542284 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 13.491129509166173 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 10.222353636901241 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 6.2998225901833225 len(cluster_0_rate_2[0])/100000: 12.0
# var_ratio: 11.292134831460674 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 14.14488468361916 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 7.607332939089295 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 12.183619160260202 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 12.837374334713187 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 14.798639858072146 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 9.568598462448255 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 10.876108811354229 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 7.946317103620474 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 14.67012388360703 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 8.372704850644011 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 5.858035817003489 len(cluster_0_rate_2[0])/100000: 13.0
# var_ratio: 6.893190740490049 len(cluster_0_rate_2[0])/100000: 14.0
# var_ratio: 5.646067415730337 len(cluster_0_rate_2[0])/100000: 15.0
# var_ratio: 7.561253279215957 len(cluster_0_rate_2[0])/100000: 16.0
# var_ratio: 6.086540760219937 len(cluster_0_rate_2[0])/100000: 16.0
# var_ratio: 11.442696629213483 len(cluster_0_rate_2[0])/100000: 17.0
# var_ratio: 12.348233772532534 len(cluster_0_rate_2[0])/100000: 17.0
# var_ratio: 6.3335959202288645 len(cluster_0_rate_2[0])/100000: 17.0
# var_ratio: 9.979095897569897 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 9.379259532142198 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 6.601555747623164 len(cluster_0_rate_2[0])/100000: 18.0
# var_ratio: 7.21178358984043 len(cluster_0_rate_2[0])/100000: 19.0
# var_ratio: 8.847445847330011 len(cluster_0_rate_2[0])/100000: 20.0
# Rate 1.5 sp/s: 0.0, 0.0, 0.0
# Rate 2 sp/s: 20.0, 20.0, 20.0
# mean(g) = nan,nan,nan

# %%
## check success
AMPA_current = pickle.load(open(data_dir+'merged_files/trial_0_rate_2.0_gex_0.842105263158_gin_1.0.in_AMPA', 'rb'),encoding='latin1')
print(len(AMPA_current))
# Out:
# 2000000
